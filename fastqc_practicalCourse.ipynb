# %% [markdown]
# <a href="https://colab.research.google.com/github/HV28/binfotron/blob/master/fastqc_practicalCourse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
################################# fastqc ###############################
# Install required tools
# !apt-get update -qq
# !apt-get install -y sra-toolkit fastqc unzip

# Install SRA toolkit
# !wget --output-document sratoolkit.tar.gz https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-ubuntu64.tar.gz
# !tar -xzf sratoolkit.tar.gz
# !rm sratoolkit.tar.gz
# !mv sratoolkit.* sratoolkit

# Add SRA toolkit to PATH
import os
os.environ['PATH'] = os.environ['PATH'] + ':' + os.getcwd() + '/sratoolkit/bin'
# !echo $PATH

# Create a folder to store the FASTQ files
# !mkdir -p mhanna/
# !mkdir -p mhanna/data

# Dictionary mapping accessions to meaningful names
samples = {
    "SRR28356705": "tripod-94-2882",
    "SRR28356707": "tripod-94-2880",
    "SRR28356706": "tripod-94-2881",
    "SRR28356708": "tripod-94-2879"
}

# Download and convert directly to uncompressed FASTQ with meaningful names
for accession, sample_name in samples.items():
    print(f"\n=== Processing {accession} -> {sample_name} ===")

    # Download SRA file
    print(f"Downloading {accession}...")
    # !prefetch {accession}

    # Convert directly to uncompressed FASTQ with custom name
    print(f"Converting to FASTQ as {sample_name}.fastq...")
    # !fastq-dump --outdir final_fastq --stdout {accession} > mhanna/data/{sample_name}.fastq

    # Clean up SRA file
    # !rm -rf ~/ncbi/public/sra/{accession}.sra

    print(f"✓ Created mhanna/data/{sample_name}.fastq")

# Verify results
print("\n=== Final Results ===")
# !ls -lh mhanna/data/
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# The following additional packages will be installed:
#   blends-common default-jre default-jre-headless fonts-dejavu-core
#   fonts-dejavu-extra libapache-pom-java libargs4j-java libatk-wrapper-java
#   libatk-wrapper-java-jni libcommons-compress-java libcommons-io-java
#   libcommons-jexl2-java libcommons-lang3-java libcommons-logging-java
#   libcommons-math3-java libcommons-parent-java libfindbin-libs-perl
#   libhtsjdk-java libjbzip2-java libjson-simple-java libkdf5-2 libncbi-vdb2
#   libncbi-wvdb2 libngs-java libngs-sdk-dev libngs-sdk2 libsis-base-java
#   libsis-base-jni libsis-jhdf5-java libsis-jhdf5-jni libsnappy-java
#   libsnappy-jni libxtst6 libxxf86dga1 med-config menu openjdk-11-jre x11-utils
# Suggested packages:
#   blends-doc libxz-java libcommons-io-java-doc libcommons-lang3-java-doc
#   libavalon-framework-java libcommons-logging-java-doc
#   libexcalibur-logkit-java liblog4j1.2-java picard-tools libjson-simple-doc
#   menu-l10n gksu | kde-runtime | ktsuss mesa-utils
# The following NEW packages will be installed:
#   blends-common default-jre default-jre-headless fastqc fonts-dejavu-core
#   fonts-dejavu-extra libapache-pom-java libargs4j-java libatk-wrapper-java
#   libatk-wrapper-java-jni libcommons-compress-java libcommons-io-java
#   libcommons-jexl2-java libcommons-lang3-java libcommons-logging-java
#   libcommons-math3-java libcommons-parent-java libfindbin-libs-perl
#   libhtsjdk-java libjbzip2-java libjson-simple-java libkdf5-2 libncbi-vdb2
#   libncbi-wvdb2 libngs-java libngs-sdk-dev libngs-sdk2 libsis-base-java
#   libsis-base-jni libsis-jhdf5-java libsis-jhdf5-jni libsnappy-java
#   libsnappy-jni libxtst6 libxxf86dga1 med-config menu openjdk-11-jre
#   sra-toolkit x11-utils
# 0 upgraded, 40 newly installed, 0 to remove and 38 not upgraded.
# Need to get 20.0 MB of archives.
# After this operation, 47.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 menu amd64 2.1.47ubuntu4 [354 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 blends-common all 0.7.4ubuntu1 [15.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.27+6~us1-0ubuntu1~22.04 [214 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-math3-java all 3.6.1-3 [2,016 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjbzip2-java all 0.9.1-7 [42.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libapache-pom-java all 18-1 [4,720 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-parent-java all 43-1 [10.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-compress-java all 1.21-1 [575 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-logging-java all 1.2-2 [60.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-jexl2-java all 2.1.1-5 [251 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjson-simple-java all 2.3.0-1 [61.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libngs-sdk2 amd64 2.11.2-3 [65.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libngs-sdk-dev amd64 2.11.2-3 [111 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libngs-java amd64 2.11.2-3 [75.8 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsnappy-jni amd64 1.1.8.3-1 [6,756 B]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsnappy-java all 1.1.8.3-1 [93.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhtsjdk-java all 2.24.1+dfsg-1 [1,644 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfindbin-libs-perl all 2.190.02-1 [23.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libargs4j-java all 2.33-1.1 [137 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-io-java all 2.11.0-2 [297 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-lang3-java all 3.11-1 [526 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsis-base-jni amd64 18.09~pre1+git20180928.45fbd31+dfsg-3 [12.7 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsis-base-java all 18.09~pre1+git20180928.45fbd31+dfsg-3 [96.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsis-jhdf5-jni amd64 19.04.0+dfsg-4 [96.6 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsis-jhdf5-java all 19.04.0+dfsg-4 [1,490 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fastqc all 0.11.9+dfsg-5 [370 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkdf5-2 amd64 2.11.2+dfsg-4build2 [14.7 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libncbi-vdb2 amd64 2.11.2+dfsg-4build2 [1,364 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libncbi-wvdb2 amd64 2.11.2+dfsg-4build2 [1,252 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 sra-toolkit amd64 2.11.3+dfsg-1ubuntu1 [5,277 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 med-config all 3.7.1 [11.6 kB]
# Fetched 20.0 MB in 2s (13.1 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package menu.
# (Reading database ... 126109 files and directories currently installed.)
# Preparing to unpack .../00-menu_2.1.47ubuntu4_amd64.deb ...
# Unpacking menu (2.1.47ubuntu4) ...
# Selecting previously unselected package blends-common.
# Preparing to unpack .../01-blends-common_0.7.4ubuntu1_all.deb ...
# Unpacking blends-common (0.7.4ubuntu1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../02-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../03-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../04-openjdk-11-jre_11.0.27+6~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../05-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package libcommons-math3-java.
# Preparing to unpack .../06-libcommons-math3-java_3.6.1-3_all.deb ...
# Unpacking libcommons-math3-java (3.6.1-3) ...
# Selecting previously unselected package libjbzip2-java.
# Preparing to unpack .../07-libjbzip2-java_0.9.1-7_all.deb ...
# Unpacking libjbzip2-java (0.9.1-7) ...
# Selecting previously unselected package libapache-pom-java.
# Preparing to unpack .../08-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../09-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-compress-java.
# Preparing to unpack .../10-libcommons-compress-java_1.21-1_all.deb ...
# Unpacking libcommons-compress-java (1.21-1) ...
# Selecting previously unselected package libcommons-logging-java.
# Preparing to unpack .../11-libcommons-logging-java_1.2-2_all.deb ...
# Unpacking libcommons-logging-java (1.2-2) ...
# Selecting previously unselected package libcommons-jexl2-java.
# Preparing to unpack .../12-libcommons-jexl2-java_2.1.1-5_all.deb ...
# Unpacking libcommons-jexl2-java (2.1.1-5) ...
# Selecting previously unselected package libjson-simple-java.
# Preparing to unpack .../13-libjson-simple-java_2.3.0-1_all.deb ...
# Unpacking libjson-simple-java (2.3.0-1) ...
# Selecting previously unselected package libngs-sdk2:amd64.
# Preparing to unpack .../14-libngs-sdk2_2.11.2-3_amd64.deb ...
# Unpacking libngs-sdk2:amd64 (2.11.2-3) ...
# Selecting previously unselected package libngs-sdk-dev:amd64.
# Preparing to unpack .../15-libngs-sdk-dev_2.11.2-3_amd64.deb ...
# Unpacking libngs-sdk-dev:amd64 (2.11.2-3) ...
# Selecting previously unselected package libngs-java:amd64.
# Preparing to unpack .../16-libngs-java_2.11.2-3_amd64.deb ...
# Unpacking libngs-java:amd64 (2.11.2-3) ...
# Selecting previously unselected package libsnappy-jni.
# Preparing to unpack .../17-libsnappy-jni_1.1.8.3-1_amd64.deb ...
# Unpacking libsnappy-jni (1.1.8.3-1) ...
# Selecting previously unselected package libsnappy-java.
# Preparing to unpack .../18-libsnappy-java_1.1.8.3-1_all.deb ...
# Unpacking libsnappy-java (1.1.8.3-1) ...
# Selecting previously unselected package libhtsjdk-java.
# Preparing to unpack .../19-libhtsjdk-java_2.24.1+dfsg-1_all.deb ...
# Unpacking libhtsjdk-java (2.24.1+dfsg-1) ...
# Selecting previously unselected package libfindbin-libs-perl.
# Preparing to unpack .../20-libfindbin-libs-perl_2.190.02-1_all.deb ...
# Unpacking libfindbin-libs-perl (2.190.02-1) ...
# Selecting previously unselected package libargs4j-java.
# Preparing to unpack .../21-libargs4j-java_2.33-1.1_all.deb ...
# Unpacking libargs4j-java (2.33-1.1) ...
# Selecting previously unselected package libcommons-io-java.
# Preparing to unpack .../22-libcommons-io-java_2.11.0-2_all.deb ...
# Unpacking libcommons-io-java (2.11.0-2) ...
# Selecting previously unselected package libcommons-lang3-java.
# Preparing to unpack .../23-libcommons-lang3-java_3.11-1_all.deb ...
# Unpacking libcommons-lang3-java (3.11-1) ...
# Selecting previously unselected package libsis-base-jni.
# Preparing to unpack .../24-libsis-base-jni_18.09~pre1+git20180928.45fbd31+dfsg-3_amd64.deb ...
# Unpacking libsis-base-jni (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Selecting previously unselected package libsis-base-java.
# Preparing to unpack .../25-libsis-base-java_18.09~pre1+git20180928.45fbd31+dfsg-3_all.deb ...
# Unpacking libsis-base-java (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Selecting previously unselected package libsis-jhdf5-jni.
# Preparing to unpack .../26-libsis-jhdf5-jni_19.04.0+dfsg-4_amd64.deb ...
# Unpacking libsis-jhdf5-jni (19.04.0+dfsg-4) ...
# Selecting previously unselected package libsis-jhdf5-java.
# Preparing to unpack .../27-libsis-jhdf5-java_19.04.0+dfsg-4_all.deb ...
# Unpacking libsis-jhdf5-java (19.04.0+dfsg-4) ...
# Selecting previously unselected package fastqc.
# Preparing to unpack .../28-fastqc_0.11.9+dfsg-5_all.deb ...
# Unpacking fastqc (0.11.9+dfsg-5) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../29-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../30-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../31-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../32-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../33-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../34-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libkdf5-2.
# Preparing to unpack .../35-libkdf5-2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libkdf5-2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package libncbi-vdb2.
# Preparing to unpack .../36-libncbi-vdb2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libncbi-vdb2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package libncbi-wvdb2.
# Preparing to unpack .../37-libncbi-wvdb2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libncbi-wvdb2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package sra-toolkit.
# Preparing to unpack .../38-sra-toolkit_2.11.3+dfsg-1ubuntu1_amd64.deb ...
# Unpacking sra-toolkit (2.11.3+dfsg-1ubuntu1) ...
# Selecting previously unselected package med-config.
# Preparing to unpack .../39-med-config_3.7.1_all.deb ...
# Unpacking med-config (3.7.1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libngs-sdk2:amd64 (2.11.2-3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Setting up libfindbin-libs-perl (2.190.02-1) ...
# Setting up libncbi-vdb2 (2.11.2+dfsg-4build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libjson-simple-java (2.3.0-1) ...
# Setting up libkdf5-2 (2.11.2+dfsg-4build2) ...
# Setting up libsis-base-jni (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Setting up libncbi-wvdb2 (2.11.2+dfsg-4build2) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libjbzip2-java (0.9.1-7) ...
# Setting up libngs-sdk-dev:amd64 (2.11.2-3) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libcommons-math3-java (3.6.1-3) ...
# Setting up libsis-jhdf5-jni (19.04.0+dfsg-4) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libngs-java:amd64 (2.11.2-3) ...
# Setting up menu (2.1.47ubuntu4) ...
# Setting up libsnappy-jni (1.1.8.3-1) ...
# Setting up libargs4j-java (2.33-1.1) ...
# Setting up blends-common (0.7.4ubuntu1) ...
# Setting up sra-toolkit (2.11.3+dfsg-1ubuntu1) ...
# Setting up med-config (3.7.1) ...
# Adding group `med' (GID 107) ...
# Done.
# Setting up libcommons-parent-java (43-1) ...
# Setting up libcommons-logging-java (1.2-2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libcommons-jexl2-java (2.1.1-5) ...
# Setting up libcommons-lang3-java (3.11-1) ...
# Setting up libsnappy-java (1.1.8.3-1) ...
# Setting up libcommons-compress-java (1.21-1) ...
# Setting up libcommons-io-java (2.11.0-2) ...
# Setting up libsis-base-java (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Setting up libhtsjdk-java (2.24.1+dfsg-1) ...
# Setting up libsis-jhdf5-java (19.04.0+dfsg-4) ...
# Setting up fastqc (0.11.9+dfsg-5) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for menu (2.1.47ubuntu4) ...
# --2025-06-02 19:51:12--  https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-ubuntu64.tar.gz
# Resolving ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)... 130.14.250.12, 130.14.250.7, 130.14.250.10, ...
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92284274 (88M) [application/x-gzip]
# Saving to: ‘sratoolkit.tar.gz’
#
# sratoolkit.tar.gz   100%[===================>]  88.01M   145MB/s    in 0.6s
#
# 2025-06-02 19:51:13 (145 MB/s) - ‘sratoolkit.tar.gz’ saved [92284274/92284274]
#
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/content/sratoolkit/bin
#
# === Processing SRR28356705 -> tripod-94-2882 ===
# Downloading SRR28356705...
#
# 2025-06-02T19:51:17 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-06-02T19:51:17 prefetch.2.11.3: 1) Downloading 'SRR28356705'...
# 2025-06-02T19:51:17 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-06-02T19:51:17 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-06-02T19:51:26 prefetch.2.11.3:  HTTPS download succeed
# 2025-06-02T19:51:28 prefetch.2.11.3:  'SRR28356705' is valid
# 2025-06-02T19:51:28 prefetch.2.11.3: 1) 'SRR28356705' was downloaded successfully
# 2025-06-02T19:51:28 prefetch.2.11.3: 'SRR28356705' has 0 unresolved dependencies
# Converting to FASTQ as tripod-94-2882.fastq...
# 2025-06-02T19:51:28 fastq-dump.2.11.3 warn: stdout mode is set, some options are ignored
# Read 2202252 spots for SRR28356705
# Written 2202252 spots for SRR28356705
# ✓ Created mhanna/data/tripod-94-2882.fastq
#
# === Processing SRR28356707 -> tripod-94-2880 ===
# Downloading SRR28356707...
#
# 2025-06-02T19:51:59 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-06-02T19:51:59 prefetch.2.11.3: 1) Downloading 'SRR28356707'...
# 2025-06-02T19:51:59 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-06-02T19:51:59 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-06-02T19:52:11 prefetch.2.11.3:  HTTPS download succeed
# 2025-06-02T19:52:14 prefetch.2.11.3:  'SRR28356707' is valid
# 2025-06-02T19:52:14 prefetch.2.11.3: 1) 'SRR28356707' was downloaded successfully
# 2025-06-02T19:52:14 prefetch.2.11.3: 'SRR28356707' has 0 unresolved dependencies
# Converting to FASTQ as tripod-94-2880.fastq...
# 2025-06-02T19:52:14 fastq-dump.2.11.3 warn: stdout mode is set, some options are ignored
# Read 2605725 spots for SRR28356707
# Written 2605725 spots for SRR28356707
# ✓ Created mhanna/data/tripod-94-2880.fastq
#
# === Processing SRR28356706 -> tripod-94-2881 ===
# Downloading SRR28356706...
#
# 2025-06-02T19:52:51 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-06-02T19:52:51 prefetch.2.11.3: 1) Downloading 'SRR28356706'...
# 2025-06-02T19:52:51 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-06-02T19:52:51 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-06-02T19:52:59 prefetch.2.11.3:  HTTPS download succeed
# 2025-06-02T19:53:00 prefetch.2.11.3:  'SRR28356706' is valid
# 2025-06-02T19:53:00 prefetch.2.11.3: 1) 'SRR28356706' was downloaded successfully
# 2025-06-02T19:53:00 prefetch.2.11.3: 'SRR28356706' has 0 unresolved dependencies
# Converting to FASTQ as tripod-94-2881.fastq...
# 2025-06-02T19:53:01 fastq-dump.2.11.3 warn: stdout mode is set, some options are ignored
# Read 1435131 spots for SRR28356706
# Written 1435131 spots for SRR28356706
# ✓ Created mhanna/data/tripod-94-2881.fastq
#
# === Processing SRR28356708 -> tripod-94-2879 ===
# Downloading SRR28356708...
#
# 2025-06-02T19:53:23 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-06-02T19:53:23 prefetch.2.11.3: 1) Downloading 'SRR28356708'...
# 2025-06-02T19:53:23 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-06-02T19:53:23 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-06-02T19:53:32 prefetch.2.11.3:  HTTPS download succeed
# 2025-06-02T19:53:34 prefetch.2.11.3:  'SRR28356708' is valid
# 2025-06-02T19:53:34 prefetch.2.11.3: 1) 'SRR28356708' was downloaded successfully
# 2025-06-02T19:53:34 prefetch.2.11.3: 'SRR28356708' has 0 unresolved dependencies
# Converting to FASTQ as tripod-94-2879.fastq...
# 2025-06-02T19:53:34 fastq-dump.2.11.3 warn: stdout mode is set, some options are ignored
# Read 1869891 spots for SRR28356708
# Written 1869891 spots for SRR28356708
# ✓ Created mhanna/data/tripod-94-2879.fastq
#
# === Final Results ===
# total 5.1G
# -rw-r--r-- 1 root root 1.2G Jun  2 19:54 tripod-94-2879.fastq
# -rw-r--r-- 1 root root 1.6G Jun  2 19:52 tripod-94-2880.fastq
# -rw-r--r-- 1 root root 949M Jun  2 19:53 tripod-94-2881.fastq
# -rw-r--r-- 1 root root 1.4G Jun  2 19:51 tripod-94-2882.fastq

# %%
# Run FastQC directly on the uncompressed files
print("\n=== Running FastQC ===")
# !mkdir -p mhanna/fastqc_results
# !fastqc mhanna/data/*.fastq -o mhanna/fastqc_results/

print("\n=== FastQC Complete ===")
# !ls -lh mhanna/fastqc_results/
# Out:
# === Running FastQC ===
# Started analysis of tripod-94-2879.fastq
# Approx 5% complete for tripod-94-2879.fastq
# Approx 10% complete for tripod-94-2879.fastq
# Approx 15% complete for tripod-94-2879.fastq
# Approx 20% complete for tripod-94-2879.fastq
# Approx 25% complete for tripod-94-2879.fastq
# Approx 30% complete for tripod-94-2879.fastq
# Approx 35% complete for tripod-94-2879.fastq
# Approx 40% complete for tripod-94-2879.fastq
# Approx 45% complete for tripod-94-2879.fastq
# Approx 50% complete for tripod-94-2879.fastq
# Approx 55% complete for tripod-94-2879.fastq
# Approx 60% complete for tripod-94-2879.fastq
# Approx 65% complete for tripod-94-2879.fastq
# Approx 70% complete for tripod-94-2879.fastq
# Approx 75% complete for tripod-94-2879.fastq
# Approx 80% complete for tripod-94-2879.fastq
# Approx 85% complete for tripod-94-2879.fastq
# Approx 90% complete for tripod-94-2879.fastq
# Approx 95% complete for tripod-94-2879.fastq
# Analysis complete for tripod-94-2879.fastq
# Started analysis of tripod-94-2880.fastq
# Approx 5% complete for tripod-94-2880.fastq
# Approx 10% complete for tripod-94-2880.fastq
# Approx 15% complete for tripod-94-2880.fastq
# Approx 20% complete for tripod-94-2880.fastq
# Approx 25% complete for tripod-94-2880.fastq
# Approx 30% complete for tripod-94-2880.fastq
# Approx 35% complete for tripod-94-2880.fastq
# Approx 40% complete for tripod-94-2880.fastq
# Approx 45% complete for tripod-94-2880.fastq
# Approx 50% complete for tripod-94-2880.fastq
# Approx 55% complete for tripod-94-2880.fastq
# Approx 60% complete for tripod-94-2880.fastq
# Approx 65% complete for tripod-94-2880.fastq
# Approx 70% complete for tripod-94-2880.fastq
# Approx 75% complete for tripod-94-2880.fastq
# Approx 80% complete for tripod-94-2880.fastq
# Approx 85% complete for tripod-94-2880.fastq
# Approx 90% complete for tripod-94-2880.fastq
# Approx 95% complete for tripod-94-2880.fastq
# Analysis complete for tripod-94-2880.fastq
# Started analysis of tripod-94-2881.fastq
# Approx 5% complete for tripod-94-2881.fastq
# Approx 10% complete for tripod-94-2881.fastq
# Approx 15% complete for tripod-94-2881.fastq
# Approx 20% complete for tripod-94-2881.fastq
# Approx 25% complete for tripod-94-2881.fastq
# Approx 30% complete for tripod-94-2881.fastq
# Approx 35% complete for tripod-94-2881.fastq
# Approx 40% complete for tripod-94-2881.fastq
# Approx 45% complete for tripod-94-2881.fastq
# Approx 50% complete for tripod-94-2881.fastq
# Approx 55% complete for tripod-94-2881.fastq
# Approx 60% complete for tripod-94-2881.fastq
# Approx 65% complete for tripod-94-2881.fastq
# Approx 70% complete for tripod-94-2881.fastq
# Approx 75% complete for tripod-94-2881.fastq
# Approx 80% complete for tripod-94-2881.fastq
# Approx 85% complete for tripod-94-2881.fastq
# Approx 90% complete for tripod-94-2881.fastq
# Approx 95% complete for tripod-94-2881.fastq
# Analysis complete for tripod-94-2881.fastq
# Started analysis of tripod-94-2882.fastq
# Approx 5% complete for tripod-94-2882.fastq
# Approx 10% complete for tripod-94-2882.fastq
# Approx 15% complete for tripod-94-2882.fastq
# Approx 20% complete for tripod-94-2882.fastq
# Approx 25% complete for tripod-94-2882.fastq
# Approx 30% complete for tripod-94-2882.fastq
# Approx 35% complete for tripod-94-2882.fastq
# Approx 40% complete for tripod-94-2882.fastq
# Approx 45% complete for tripod-94-2882.fastq
# Approx 50% complete for tripod-94-2882.fastq
# Approx 55% complete for tripod-94-2882.fastq
# Approx 60% complete for tripod-94-2882.fastq
# Approx 65% complete for tripod-94-2882.fastq
# Approx 70% complete for tripod-94-2882.fastq
# Approx 75% complete for tripod-94-2882.fastq
# Approx 80% complete for tripod-94-2882.fastq
# Approx 85% complete for tripod-94-2882.fastq
# Approx 90% complete for tripod-94-2882.fastq
# Approx 95% complete for tripod-94-2882.fastq
# Analysis complete for tripod-94-2882.fastq
#
# === FastQC Complete ===
# total 5.3M
# -rw-r--r-- 1 root root 783K Jun  2 19:55 tripod-94-2879_fastqc.html
# -rw-r--r-- 1 root root 543K Jun  2 19:55 tripod-94-2879_fastqc.zip
# -rw-r--r-- 1 root root 786K Jun  2 19:55 tripod-94-2880_fastqc.html
# -rw-r--r-- 1 root root 545K Jun  2 19:55 tripod-94-2880_fastqc.zip
# -rw-r--r-- 1 root root 789K Jun  2 19:56 tripod-94-2881_fastqc.html
# -rw-r--r-- 1 root root 554K Jun  2 19:56 tripod-94-2881_fastqc.zip
# -rw-r--r-- 1 root root 787K Jun  2 19:56 tripod-94-2882_fastqc.html
# -rw-r--r-- 1 root root 550K Jun  2 19:56 tripod-94-2882_fastqc.zip

# %%
import os
import glob
import zipfile
from google.colab import files

# Download all HTML files as a zip
def download_all_reports():
    """Create and download a zip file with all HTML reports"""
    html_files = glob.glob("mhanna/fastqc_results/*.html")

    if not html_files:
        print("No HTML files found!")
        return

    # Create zip file
    zip_filename = "fastqc_reports.zip"
    with zipfile.ZipFile(zip_filename, 'w') as zipf:
        for html_file in html_files:
            zipf.write(html_file, os.path.basename(html_file))

    print(f"Created {zip_filename} with {len(html_files)} HTML reports")
    files.download(zip_filename)

download_all_reports()
